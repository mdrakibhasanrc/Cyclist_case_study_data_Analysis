# %% [markdown]
# # Project: Cyclistic Case Study Analysis 2022
# Problem Statment: Key business task/question to solve for this case: How do annual members and casual riders use Cyclistic bikes differently?

# %% [markdown]
# # Import Library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Loda Dataset:

# %%
df=pd.read_csv('tripdata.csv')

# %%
df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       620BC6107255BF4C  electric_bike  2021-10-22 12:46:42
# 1       4471C70731AB2E45  electric_bike  2021-10-21 09:12:37
# 2       26CA69D43D15EE14  electric_bike  2021-10-16 16:28:39
# 3       362947F0437E1514  electric_bike  2021-10-16 16:17:48
# 4       BB731DE2F2EC51C5  electric_bike  2021-10-20 23:17:54
# ...                  ...            ...                  ...
# 631221  BA077FDD42DABF12   classic_bike  2021-10-14 21:45:05
# 631222  B7D99254E798AA6B   classic_bike  2021-10-02 15:28:28
# 631223  BCCFD66DA466400F  electric_bike  2021-10-08 16:47:10
# 631224  623E0F6F50CDD6E4   classic_bike  2021-10-08 07:49:47
# 631225  83FA6AC52B7B7A7B   classic_bike  2021-10-02 12:55:45
#
#                    ended_at           start_station_name start_station_id  \
# 0       2021-10-22 12:49:50     Kingsbury St & Kinzie St     KA1503000043
# 1       2021-10-21 09:14:14                          NaN              NaN
# ...

# %% [markdown]
# # Understand Data

# %%
#show first five rows
df.head(5)
# Out:
#             ride_id  rideable_type           started_at             ended_at  \
# 0  620BC6107255BF4C  electric_bike  2021-10-22 12:46:42  2021-10-22 12:49:50
# 1  4471C70731AB2E45  electric_bike  2021-10-21 09:12:37  2021-10-21 09:14:14
# 2  26CA69D43D15EE14  electric_bike  2021-10-16 16:28:39  2021-10-16 16:36:26
# 3  362947F0437E1514  electric_bike  2021-10-16 16:17:48  2021-10-16 16:19:03
# 4  BB731DE2F2EC51C5  electric_bike  2021-10-20 23:17:54  2021-10-20 23:26:10
#
#          start_station_name start_station_id end_station_name end_station_id  \
# 0  Kingsbury St & Kinzie St     KA1503000043              NaN            NaN
# 1                       NaN              NaN              NaN            NaN
# 2                       NaN              NaN              NaN            NaN
# 3                       NaN              NaN              NaN            NaN
# 4                       NaN              NaN              NaN            NaN
#
# ...

# %%
#show last five rows
df.tail(5)
# Out:
#                  ride_id  rideable_type           started_at  \
# 631221  BA077FDD42DABF12   classic_bike  2021-10-14 21:45:05
# 631222  B7D99254E798AA6B   classic_bike  2021-10-02 15:28:28
# 631223  BCCFD66DA466400F  electric_bike  2021-10-08 16:47:10
# 631224  623E0F6F50CDD6E4   classic_bike  2021-10-08 07:49:47
# 631225  83FA6AC52B7B7A7B   classic_bike  2021-10-02 12:55:45
#
#                    ended_at           start_station_name start_station_id  \
# 631221  2021-10-14 22:07:25    Franklin St & Chicago Ave            13017
# 631222  2021-10-02 15:51:02      Streeter Dr & Grand Ave            13022
# 631223  2021-10-08 16:52:43        Calumet Ave & 21st St            15546
# 631224  2021-10-08 07:55:15        Calumet Ave & 21st St            15546
# 631225  2021-10-02 13:21:10  Winthrop Ave & Lawrence Ave     TA1308000021
#
#                      end_station_name end_station_id  start_lat  start_lng  \
# ...

# %%
#show random five rows
df.sample(5)
# Out:
#                  ride_id  rideable_type           started_at  \
# 262017  ECA0FFB2097FDA2C   classic_bike  2021-10-19 11:31:23
# 41031   8A11018961351BCB   classic_bike  2021-10-04 18:25:22
# 232783  3315C719E34050B0  electric_bike  2021-10-02 13:26:19
# 203030  B3CE842231C08C5F  electric_bike  2021-10-06 10:09:42
# 384836  27ECED87C39D29CD   classic_bike  2021-10-08 13:43:31
#
#                    ended_at          start_station_name start_station_id  \
# 262017  2021-10-19 11:52:41  Aberdeen St & Jackson Blvd            13157
# 41031   2021-10-04 18:32:00   Leavitt St & Armitage Ave     TA1309000029
# 232783  2021-10-02 13:45:31   Lincoln Park Conservatory              LP-
# 203030  2021-10-06 10:20:51    Loomis St & Lexington St            13332
# 384836  2021-10-08 13:48:19       Shields Ave & 31st St     KA1503000038
#
#                       end_station_name end_station_id  start_lat  start_lng  \
# 262017        Leavitt St & Chicago Ave          18058  41.877726 -87.654787
# ...

# %%
# show columns name
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
# show data types
df.dtypes
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
# show data shape
df.shape
# Out:
# (631226, 13)

# %%
# show info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631226 entries, 0 to 631225
# Data columns (total 13 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ride_id             631226 non-null  object
#  1   rideable_type       631226 non-null  object
#  2   started_at          631226 non-null  object
#  3   ended_at            631226 non-null  object
#  4   start_station_name  523016 non-null  object
#  5   start_station_id    523016 non-null  object
#  6   end_station_name    516392 non-null  object
#  7   end_station_id      516392 non-null  object
#  8   start_lat           631226 non-null  float64
#  9   start_lng           631226 non-null  float64
#  10  end_lat             630742 non-null  float64
#  11  end_lng             630742 non-null  float64
#  12  member_casual       631226 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 62.6+ MB

# %% [markdown]
# # Data Cleaning:

# %%
# show columns name
df.columns
# Out:
# Index(['ride_id', 'rideable_type', 'started_at', 'ended_at',
#        'start_station_name', 'start_station_id', 'end_station_name',
#        'end_station_id', 'start_lat', 'start_lng', 'end_lat', 'end_lng',
#        'member_casual'],
#       dtype='object')

# %%
df.head(2)
# Out:
#             ride_id  rideable_type          started_at            ended_at  \
# 0  620BC6107255BF4C  electric_bike 2021-10-22 12:46:42 2021-10-22 12:49:50
# 1  4471C70731AB2E45  electric_bike 2021-10-21 09:12:37 2021-10-21 09:14:14
#
#          start_station_name start_station_id  start_lat  start_lng  end_lat  \
# 0  Kingsbury St & Kinzie St     KA1503000043  41.889186 -87.638495    41.89
# 1                       NaN              NaN  41.930000 -87.700000    41.93
#
#    end_lng member_casual     Start_Hour Start_Minutes Start_Seconds
# 0   -87.63        member  2021-10-22 12            49            50
# 1   -87.71        member  2021-10-21 09            14            14

# %%
# drop unwanted columns
df.drop(columns=['end_station_name','end_station_id'],axis=1,inplace=True)

# %%
# change data type
df['started_at']=pd.to_datetime(df['started_at'])
df['ended_at']=pd.to_datetime(df['ended_at'])

# %%
df[['Start_Hour','Start_Minutes','Start_Seconds']]=df['started_at'].astype('str').str.split(':',expand=True)

# %%
df['Start_hour']=df['Start_Hour'].astype('str').str.split(' ').str[1]

# %%
df['Start_Date']=df['Start_Hour'].astype('str').str.split(' ').str[0]

# %%
df.drop(columns=['started_at','ended_at','end_lat','end_lng','Start_Hour'],axis=1,inplace=True)

# %%
df.drop(columns=['Start_Minutes','Start_Seconds'],axis=1,inplace=True)

# %%
df['Start_Date']=pd.to_datetime(df['Start_Date'])

# %%
df['Day_of_week']=df['Start_Date'].dt.day_name()

# %%
df['Month']=df['Start_Date'].dt.month_name()

# %%
df.head(2)
# Out:
#             ride_id  rideable_type        start_station_name start_station_id  \
# 0  620BC6107255BF4C  electric_bike  Kingsbury St & Kinzie St     KA1503000043
# 1  4471C70731AB2E45  electric_bike                       NaN              NaN
#
#    start_lat  start_lng member_casual Start_hour Start_Date Day_of_week  \
# 0  41.889186 -87.638495        member         12 2021-10-22      Friday
# 1  41.930000 -87.700000        member         09 2021-10-21    Thursday
#
#      Month
# 0  October
# 1  October

# %%
# check duplicated value
df.duplicated().sum()
# Out:
# 0

# %%
# check null values
df.isnull().sum()
# Out:
# ride_id                    0
# rideable_type              0
# start_station_name    108210
# start_station_id      108210
# start_lat                  0
# start_lng                  0
# member_casual              0
# Start_hour                 0
# Start_Date                 0
# Day_of_week                0
# Month                      0
# dtype: int64

# %%
# drop all null value
new=df.dropna()

# %%
new.isnull().sum()
# Out:
# ride_id               0
# rideable_type         0
# start_station_name    0
# start_station_id      0
# start_lat             0
# start_lng             0
# member_casual         0
# Start_hour            0
# Start_Date            0
# Day_of_week           0
# Month                 0
# dtype: int64

# %%
#check datatypes
new.dtypes
# Out:
# ride_id                       object
# rideable_type                 object
# start_station_name            object
# start_station_id              object
# start_lat                    float64
# start_lng                    float64
# member_casual                 object
# Start_hour                    object
# Start_Date            datetime64[ns]
# Day_of_week                   object
# Month                         object
# dtype: object

# %%
# show data shape
df.shape
# Out:
# (631226, 11)

# %%
# expoert data
new.to_csv(r"G:\Data\clean_data.csv")

# %% [markdown]
# # Now Our Dataset is clean
